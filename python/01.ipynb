# %% [markdown]
# # 第 1 课 · Python 入门：环境、变量与基本类型
#
# 按 `Shift+Enter` 逐格运行。每格运行后观察输出，再进入下一格。

# %%
print('Hello,world')
# Out:
# Hello,world

# %%
# 1. 数值类
x = 10          # int 整数
y = 5.3         # float 浮点数
print("x =", x)
print("y =", y)
print("Type of x:", type(x))
print("Type of y:", type(y))

# 2. 字符串 str
name = "小明"
print("name =", name)
print("Type of name:", type(name))

# 3. 布尔 bool
is_student = True
print("is_student =", is_student)
print("Type of is_student:", type(is_student))

# 4. 列表 list []
fruits = ["apple", "banana", "cherry"]
print("fruits =", fruits)
print("Type of fruits:", type(fruits))

# 5. 字典 dict {key:value}
person = {"name": "小明", "age": 20}
print("person =", person)
print("Type of person:", type(person))

# 6. 元组 tuple () 不可修改
coordinates = (10.0, 20.0)
print("coordinates =", coordinates)
print("Type of coordinates:", type(coordinates))

# 7. 集合 set {} 自动去重，无序
unique_numbers = {1, 2, 3, 4, 5}
print("unique_numbers =", unique_numbers)
print("Type of unique_numbers:", type(unique_numbers))

# 8. NoneType 空值
nothing = None
print("nothing =", nothing)
print("Type of nothing:", type(nothing))

# %%
# 变量的运算（x 和 y 来自上一格：x = 10, y = 5.3）
print("x + y =", x + y)   # 加法
print("x - y =", x - y)   # 减法
print("x * y =", x * y)   # 乘法
print("x / y =", x / y)   # 除法（结果一定是小数 float）
print("x // y =", x // y) # 地板除，向下取整，舍弃小数部分
print("x % y =", x % y)   # 取模（求余数）
print("x ** y =", x ** y) # 幂运算，x 的 y 次方
